# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from utils.plot_keypoints import show_keypoints

# %%
#fb_data = pd.read_csv('data/full_body.csv')
fb_data = pd.read_csv('data/imputed_full_body.csv')

# %%
fb_data
# Out:
#         nose_x  nose_y  left_eye_x  left_eye_y  right_eye_x  right_eye_y  \
# 0       670.79  278.54      672.53      276.80       669.33       276.84
# 1       670.59  278.36      672.35      276.72       669.16       276.74
# 2       670.50  278.39      672.29      276.75       669.06       276.78
# 3       670.49  278.43      672.24      276.77       668.98       276.81
# 4       670.54  278.39      672.16      276.70       668.93       276.77
# ...        ...     ...         ...         ...          ...          ...
# 140871  264.26  251.87      265.97      249.19       261.93       249.54
# 140872  332.91  238.93      334.42      236.78       330.78       236.94
# 140873  334.58  239.43      335.88      237.21       332.27       237.36
# 140874  334.87  240.07      336.13      237.77       332.61       238.09
# 140875  335.06  240.23      336.35      237.94       332.78       238.26
#
#         left_ear_x  left_ear_y  right_ear_x  right_ear_y  ...  right_hip_x  \
# 0       675.250000  277.910000       667.14       277.75  ...       663.08
# 1       675.200000  277.910000       667.10       277.68  ...       663.10
# 2       675.090000  277.890000       666.95       277.59  ...       663.07
# 3       675.090000  277.920000       666.81       277.74  ...       663.03
# 4       674.870000  277.800000       666.57       277.89  ...       662.88
# ...            ...         ...          ...          ...  ...          ...
# 140871  269.770000  249.170000       258.29       249.65  ...       260.60
# 140872  335.605364  237.774057       326.42       237.79  ...       326.29
# 140873  336.892987  238.070663       328.03       238.13  ...       327.28
# 140874  338.740000  237.740000       328.64       238.66  ...       328.48
# 140875  338.830000  237.680000       328.66       238.70  ...       328.28
#
#         right_hip_y  left_knee_x  left_knee_y  right_knee_x  right_knee_y  \
# 0            311.66   671.870000   333.780000        661.95        333.37
# 1            311.44   671.510000   333.730000        661.97        333.11
# 2            311.42   671.510000   333.850000        661.94        333.21
# 3            311.28   671.260000   333.480000        661.58        331.99
# 4            311.34   671.120000   333.490000        661.34        331.94
# ...             ...          ...          ...           ...           ...
# 140871       299.52   277.425434   329.148878        261.55        330.24
# 140872       282.01   336.050000   307.750000        325.88        308.91
# 140873       283.02   336.120000   309.790000        326.18        309.83
# 140874       286.38   338.210000   308.990000        327.91        311.20
# 140875       283.98   337.780000   309.190000        329.25        310.07
#
#         left_ankle_x  left_ankle_y  right_ankle_x  right_ankle_y
# 0         669.330000    353.900000     658.410000     353.790000
# 1         669.150000    353.840000     658.440000     353.460000
# 2         669.080000    353.980000     658.330000     353.180000
# 3         668.910000    353.410000     658.260000     352.930000
# 4         669.100000    353.390000     658.040000     352.460000
# ...              ...           ...            ...            ...
# 140871    279.254800    356.062066     262.182302     356.689498
# 140872    333.070000    327.300000     323.970000     329.980000
# 140873    332.720000    329.950000     323.830000     332.950000
# 140874    341.447527    331.956340     326.250000     332.110000
# 140875    334.060000    328.220000     325.222654     329.936514
#
# [140876 rows x 34 columns]

# %%
fb_data.describe()
# Out:
#               nose_x         nose_y     left_eye_x     left_eye_y  \
# count  140876.000000  140876.000000  140876.000000  140876.000000
# mean      313.550913     106.445971     318.942695     100.711265
# std       154.968960      68.548738     155.991267      69.592163
# min        14.710000       5.730000      22.300000      -1.229434
# 25%       211.330000      63.020000     216.190000      57.160000
# 50%       298.525000      88.320000     305.605000      79.420000
# 75%       389.392500     135.030000     397.140000     131.321123
# max      1222.870000     530.700000    1227.660000     527.200000
#
#          right_eye_x    right_eye_y     left_ear_x     left_ear_y  \
# count  140876.000000  140876.000000  140876.000000  140876.000000
# mean      308.179543     100.805258     327.179626     104.419759
# std       154.864919      69.519859     158.737058      69.698517
# min         6.710000      -1.805652      22.397498      -3.052794
# 25%       205.820000      57.400000     219.860000      61.040000
# 50%       291.100000      79.440000     316.390000      85.190000
# 75%       382.740000     130.415139     410.570000     133.781828
# max      1217.250000     527.020000    1234.880000     529.150000
#
#          right_ear_x    right_ear_y  ...    right_hip_x    right_hip_y  \
# count  140876.000000  140876.000000  ...  140876.000000  140876.000000
# mean      300.762592     104.717805  ...     296.359262     221.977024
# std       156.356762      69.409098  ...     155.998538      92.920226
# min        -4.593999      -7.989247  ...      11.320000      46.900000
# 25%       193.922500      61.483608  ...     187.530000     157.127500
# 50%       282.360000      85.822084  ...     275.955000     210.370000
# 75%       376.610000     133.883093  ...     369.002500     283.660000
# max      1244.640000     529.000000  ...    1244.870000     708.190000
#
#          left_knee_x    left_knee_y   right_knee_x   right_knee_y  \
# count  140876.000000  140876.000000  140876.000000  140876.000000
# mean      326.146190     267.892098     293.428092     267.570287
# std       157.369782     106.195195     153.744881     106.452636
# min        17.450000      64.570000       0.050000      60.183881
# 25%       220.787500     197.113640     186.740000     197.385000
# 50%       313.719080     256.990000     274.260000     258.020000
# 75%       406.320000     346.770000     366.480000     345.649611
# max      1226.670000     863.381391    1225.910000     887.772113
#
#         left_ankle_x   left_ankle_y  right_ankle_x  right_ankle_y
# count  140876.000000  140876.000000  140876.000000  140876.000000
# mean      323.204075     335.497495     295.355343     334.188320
# std       158.148009     146.281410     153.551750     145.365592
# min       -23.574631      88.190000     -28.437328      87.780000
# 25%       214.667952     233.010000     190.191215     231.400000
# 50%       308.910037     307.690000     276.450000     307.930000
# 75%       404.480000     444.501712     367.462955     445.275278
# max      1224.390000    1169.050549    1206.470000    1196.018768
#
# [8 rows x 34 columns]

# %%
mean_points_raw = fb_data.mean()
mean_predictions = mean_points_raw.values.reshape(-1, 2)
mean_predictions
# Out:
# array([[313.55091319, 106.44597137],
#        [318.94269489, 100.71126511],
#        [308.17954279, 100.80525841],
#        [327.17962607, 104.41975855],
#        [300.76259177, 104.71780461],
#        [341.59566658, 138.87480671],
#        [287.35972603, 139.04807802],
#        [352.83834907, 181.92397431],
#        [275.62926949, 182.06640904],
#        [342.17658497, 184.48164459],
#        [284.46812294, 185.95998865],
#        [330.93234542, 222.36354739],
#        [296.35926226, 221.9770238 ],
#        [326.14618962, 267.89209813],
#        [293.42809209, 267.57028718],
#        [323.20407502, 335.49749495],
#        [295.35534265, 334.18831962]])

# %%
show_keypoints(mean_predictions, save_path='Results/mean_points.jpg')

# %%
# Calcular a correlação de Pearson
plt.figure(figsize=(20,15))
plt.title("Correlação de Pearson")
sns.heatmap(fb_data.corr(numeric_only=True, method='pearson'), annot=True, cmap='Blues')
plt.show()

# %%
# Calcular a correlação de Spearman
plt.figure(figsize=(20,15))
plt.title("Correlação de Spearman")
sns.heatmap(fb_data.corr(numeric_only=True, method='spearman'), annot=True, cmap='Blues')
plt.show()

# %%
num_cols = 34
num_rows = (num_cols + 1) // 2
fig, axes = plt.subplots(nrows=num_rows, ncols=2, figsize=(15, num_rows * 5))

axes = axes.flatten()

# Iterate through columns and create histograms using seaborn
for i, column in enumerate(fb_data.columns):
    ax = axes[i]
    sns.histplot(data=fb_data, x=column, kde=True, ax=ax)
    ax.set_title(column)
    ax.set_xlabel('Value')
    ax.set_ylabel('Frequency')

# If there are unused subplots, remove them
if num_cols < len(axes):
    for i in range(num_cols, len(axes)):
        fig.delaxes(axes[i])


plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(20, 15))
sns.stripplot(data=fb_data, orient='h', palette='Set2', jitter=False)
plt.xlabel('Values')
plt.title('Dot Plot of Columns')
plt.show()
